# %%
#Dependencies 
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
import scipy.stats as st
from scipy.stats import linregress
from scipy.stats import sem
import seaborn as sns
import pymongo

# Study data files
less_than_fifty_path = "Death Risk Factor(15-49).csv"
more_than_fifty_path = "Death Risk Factor(50-69).csv"
number_path = "Number of Deaths by Risk Factors.csv"

# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.deathDB


# Import the CSV into a pandas DataFrame

less_than_fifty_df = pd.read_csv(less_than_fifty_path)


# Display the data table for preview
less_than_fifty_df
# Out:
#            Country  Year Code  High Blood Pressure (15-49)  Alcohol (15-49)  \
# 0        Australia  1990  AUS                          766             1596
# 1        Australia  1991  AUS                          755             1554
# 2        Australia  1992  AUS                          752             1529
# 3        Australia  1993  AUS                          738             1505
# 4        Australia  1994  AUS                          746             1533
# ..             ...   ...  ...                          ...              ...
# 295  United States  2015  USA                        15624            28048
# 296  United States  2016  USA                        16258            28828
# 297  United States  2017  USA                        16276            28326
# 298  United States  2018  USA                        16096            27432
# 299  United States  2019  USA                        15823            26793
#
#      High BMI (15-49)  Smoking (15-49)  Drug Use (15-49)
# ...

# %%
less_than_fifty_df.Country.value_counts()
# Out:
# Australia        30
# Brazil           30
# England          30
# Ghana            30
# Japan            30
# Mexico           30
# Morocco          30
# Netherlands      30
# South Korea      30
# United States    30
# Name: Country, dtype: int64

# %%
Australia = []
Brazil = []
England = []
Ghana = []
Japan = []
Mexico = []
Morocco = []
Netherlands = []
South_Korea = []
United_States = []

# %%
less_than_fifty_df= less_than_fifty_df.groupby([less_than_fifty_df.Country, less_than_fifty_df.Code, less_than_fifty_df.Year]).sum()
less_than_fifty_df
# Out:
#                          High Blood Pressure (15-49)  Alcohol (15-49)  \
# Country       Code Year
# Australia     AUS  1990                          766             1596
#                    1991                          755             1554
#                    1992                          752             1529
#                    1993                          738             1505
#                    1994                          746             1533
# ...                                              ...              ...
# United States USA  2015                        15624            28048
#                    2016                        16258            28828
#                    2017                        16276            28326
#                    2018                        16096            27432
#                    2019                        15823            26793
#
#                          High BMI (15-49)  Smoking (15-49)  Drug Use (15-49)
# Country       Code Year
# ...

# %%
more_than_fifty_df = pd.read_csv(more_than_fifty_path)

more_than_fifty_df= more_than_fifty_df.groupby([more_than_fifty_df.Country, more_than_fifty_df.Code, more_than_fifty_df.Year]).sum()
# Display the data table for preview
more_than_fifty_df
# Out:
#                          High Blood Pressure (50-69)  Alcohol (50-69)  \
# Country       Code Year
# Australia     AUS  1990                         7298             2530
#                    1991                         6925             2458
#                    1992                         6648             2415
#                    1993                         6279             2352
#                    1994                         6039             2336
# ...                                              ...              ...
# United States USA  2015                       102068            63016
#                    2016                       106370            65206
#                    2017                       106153            64988
#                    2018                       107955            65715
#                    2019                       108984            65842
#
#                          High BMI (50-69)  Smoking (50-69)  Drug Use (50-69)
# Country       Code Year
# ...

# %%
number_df = pd.read_csv(number_path)
number_df
# Out:
#            Entity Code  Year   Outdoor air pollution   \
# 0     Afghanistan  AFG  1990                     3169
# 1     Afghanistan  AFG  1991                     3222
# 2     Afghanistan  AFG  1992                     3395
# 3     Afghanistan  AFG  1993                     3623
# 4     Afghanistan  AFG  1994                     3788
# ...           ...  ...   ...                      ...
# 6835     Zimbabwe  ZWE  2015                     2835
# 6836     Zimbabwe  ZWE  2016                     2781
# 6837     Zimbabwe  ZWE  2017                     2700
# 6838     Zimbabwe  ZWE  2018                     2669
# 6839     Zimbabwe  ZWE  2019                     2680
#
#       High systolic blood pressure   Diet high in sodium  \
# 0                             25633                 1045
# 1                             25872                 1055
# 2                             26309                 1075
# 3                             26961                 1103
# ...

# %%
country = number_df.groupby([number_df.Entity, number_df.Year]).sum()
country
# Out:
#                    Outdoor air pollution   High systolic blood pressure   \
# Entity      Year
# Afghanistan 1990                     3169                          25633
#             1991                     3222                          25872
#             1992                     3395                          26309
#             1993                     3623                          26961
#             1994                     3788                          27658
# ...                                   ...                            ...
# Zimbabwe    2015                     2835                          11483
#             2016                     2781                          11663
#             2017                     2700                          11819
#             2018                     2669                          12002
#             2019                     2680                          12241
#
#                   Diet high in sodium   Diet low in whole grains   \
# ...

# %%
country.columns
reduced = country[['Alcohol use ','High systolic blood pressure ',' Smoking ',' High body-mass index ', 
                   ' Drug use - Sex: Both - Age: All Ages (Number)']]
reduced
# Out:
#                   Alcohol use   High systolic blood pressure    Smoking   \
# Entity      Year
# Afghanistan 1990           356                          25633       5174
#             1991           364                          25872       5247
#             1992           376                          26309       5363
#             1993           389                          26961       5522
#             1994           399                          27658       5689
# ...                        ...                            ...        ...
# Zimbabwe    2015          4854                          11483       8409
#             2016          4915                          11663       8511
#             2017          4992                          11819       8598
#             2018          5044                          12002       8699
#             2019          5156                          12241       8838
#
#                    High body-mass index   \
# Entity      Year
# ...

# %%
merge.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 merge.info()
#
# NameError: name 'merge' is not defined

# %%
merged= reduced.rename(columns = {' Drug use - Sex: Both - Age: All Ages (Number)': 'Drug Use', 
                                " Smoking ":"Smoking", 
                                " High body-mass index ":"High body-mass index"})
merged
# Out:
#                   Alcohol use   High systolic blood pressure   Smoking  \
# Entity      Year
# Afghanistan 1990           356                          25633     5174
#             1991           364                          25872     5247
#             1992           376                          26309     5363
#             1993           389                          26961     5522
#             1994           399                          27658     5689
# ...                        ...                            ...      ...
# Zimbabwe    2015          4854                          11483     8409
#             2016          4915                          11663     8511
#             2017          4992                          11819     8598
#             2018          5044                          12002     8699
#             2019          5156                          12241     8838
#
#                   High body-mass index  Drug Use
# Entity      Year
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6840 entries, ('Afghanistan', 1990) to ('Zimbabwe', 2019)
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Alcohol use                    6840 non-null   int64
#  1   High systolic blood pressure   6840 non-null   int64
#  2   Smoking                        6840 non-null   int64
#  3   High body-mass index           6840 non-null   int64
#  4   Drug Use                       6840 non-null   int64
# dtypes: int64(5)
# memory usage: 289.3+ KB

# %%
merged.to_csv('Metadata.csv')

# %%
merged.to_json("Metadata.json")

# %%
merged.to_html("data.html")

# %%
merged.to_dict()
# Out:
# {'Alcohol use ': {('Afghanistan', 1990): 356,
#   ('Afghanistan', 1991): 364,
#   ('Afghanistan', 1992): 376,
#   ('Afghanistan', 1993): 389,
#   ('Afghanistan', 1994): 399,
#   ('Afghanistan', 1995): 406,
#   ('Afghanistan', 1996): 413,
#   ('Afghanistan', 1997): 420,
#   ('Afghanistan', 1998): 425,
#   ('Afghanistan', 1999): 426,
#   ('Afghanistan', 2000): 427,
#   ('Afghanistan', 2001): 432,
#   ('Afghanistan', 2002): 432,
#   ('Afghanistan', 2003): 437,
#   ('Afghanistan', 2004): 445,
#   ('Afghanistan', 2005): 452,
#   ('Afghanistan', 2006): 456,
#   ('Afghanistan', 2007): 465,
#   ('Afghanistan', 2008): 478,
#   ('Afghanistan', 2009): 485,
#   ('Afghanistan', 2010): 492,
#   ('Afghanistan', 2011): 496,
#   ('Afghanistan', 2012): 502,
#   ('Afghanistan', 2013): 508,
#   ('Afghanistan', 2014): 514,
#   ('Afghanistan', 2015): 522,
#   ('Afghanistan', 2016): 540,
#   ('Afghanistan', 2017): 564,
#   ('Afghanistan', 2018): 575,
#   ('Afghanistan', 2019): 583,
# ...
